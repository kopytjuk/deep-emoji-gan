# %% [markdown]
# # Generate yellow smiley faces 🙂

# %% [markdown]
# ## load dependencies
# * matplotlib for plotting
# * numpy for array handling
# * json for loading emoji description
# * mpimg and glob for reading PNG
# * tensorflow for GAN

# %%
# %matplotlib inline

import pickle as pkl

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import tensorflow as tf
import json
import glob
import random
from pprint import pprint

# %% [markdown]
# ## filter and load emoji files

# %%
# filter only person emojis without tones
with open('emoji-data/emoji.json') as data_file:
    emojis = json.load(data_file)

#smileys = [e for e in emojis if e["category"] != "Symbols" and e["category"] != "Flags" and e["category"] != "Regional"]
smileys = [e for e in emojis if e["category"] == "People"]


pprint("minimized dictionary: {} left out of {} emojis".format(len(smileys), len(emojis)))
pprint(smileys[3])
# Out:
# 'minimized dictionary: 314 left out of 1489 emojis'
# {'added_in': '1.1',
#  'au': None,
#  'category': 'People',
#  'docomo': None,
#  'google': None,
#  'has_img_apple': True,
#  'has_img_emojione': True,
#  'has_img_facebook': True,
#  'has_img_google': True,
#  'has_img_messenger': False,
#  'has_img_twitter': True,
#  'image': '2639.png',
#  'name': 'WHITE FROWNING FACE',
#  'sheet_x': 1,
#  'sheet_y': 16,
#  'short_name': 'white_frowning_face',
#  'short_names': ['white_frowning_face'],
#  'softbank': None,
#  'sort_order': 38,
#  'text': None,
#  'texts': None,
#  'unified': '2639',
#  'variations': ['2639-FE0F']}

# %%
# filter all files for the given smiley unicodes
paths = [
    "emoji-data/img-apple-64",
    "emoji-data/img-emojione-64",
    "emoji-data/img-facebook-64",
    "emoji-data/img-google-64",
    "emoji-data/img-messenger-64",
    "emoji-data/img-twitter-64"
]
filenames = [s["image"] for s in smileys]
filepaths = []
for p in paths:
    image_paths = glob.glob(p + "/*.png")
    filtered = [p for p in image_paths if p.split("/")[-1] in filenames]
    filepaths = filepaths + filtered

# %%
def is_emoji(img):
    yellowishness = np.sum(np.logical_and(np.logical_and(img[:, :, 0] > 0.6, np.logical_and(img[:, :, 1] > 0.6, img[:, :, 3] > 0.8)), img[:, :, 2] < 0.6)) / np.sum(img[:, :, 2] < 0.6) 
    transparencyness = np.sum(img[:, :, 3] > 0.8) / (64 * 64)
    return yellowishness > 0.5 and transparencyness > 0.7

# %%
# strip transparency dimension (because RGB channels are crazy in transparencent spaces)
def strip_transparency(i):
    px_transparent = i[:, :, 3] < 0.1
    i[px_transparent, 0:3] = 1
    i = i[:, :, 0:3]
    return i

# %%
# load all files
images = [mpimg.imread(f) for f in filepaths]
images = [i for i in images if i.shape == (64, 64, 4)]
images = [i for i in images if is_emoji(i)]
images = [strip_transparency(i) for i in images]

pprint(len(images))
# Out:
# 273

# %%
# display random emojis
column_count = 2 # emojis per column
display_count = column_count**2 # total number of emojis to show (aligns neatly if it's a square)

f, axarr = plt.subplots(display_count//column_count, column_count, sharex=True, sharey=True, figsize=(5,5))
for (i, img) in enumerate(random.sample(images, display_count)):
    a = axarr[i%(display_count//column_count), i//(display_count//column_count)]
    yellowishness = np.sum(np.logical_and(np.logical_and(img[:, :, 0] > 0.6, img[:, :, 1] > 0.6), img[:, :, 2] < 0.6)) / np.sum(img[:, :, 2] < 0.6) 
    print("y: {}".format(yellowishness))
    a.axis("off")
    a.imshow(img)
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# y: 0.923581809657759
# y: 0.769951534733441
# y: 0.798941798941799
# y: 0.8809082483781279

# %%
# figuring out how to filter for round yellow emojis..
i = images[0]
yellow_pixels = np.logical_and(i[:, :, 0] > 0.7, img[:, :, 1] > 0.7)
f, axarr = plt.subplots(1, 2, figsize=(10,10))

o = np.copy(i)
pixls = np.logical_and(np.logical_and(o[:, :, 0] > 0.6, o[:, :, 1] > 0.6), o[:, :, 2] < 0.6)
o[pixls] = [1, 0, 1]
axarr[0].imshow(o)
axarr[1].imshow(i)

# %% [markdown]
# ## emojis

# %%
# plot emojis in order
lines = 10
f, axarr = plt.subplots(lines, lines, sharex=True, sharey=True, figsize=(5,5))
for i in range(lines**2):
    a = axarr[i%(lines), i//(lines)]
    img = images[i]
    a.axis("off")
    a.imshow(img)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
# only select one emoji for training
images = [images[99]]
plt.imshow(images[0])

# %% [markdown]
# ## preprocessing functions

# %%
scale_min_val=-1
scale_max_val=1
def scale(x):
    x = x / 255
    
    # scale to feature_range
    x = x * (scale_max_val - scale_min_val) + scale_min_val
    return x

def unscale(x):
    # scale to (0, 255)
   
    x = (x - scale_min_val) / (scale_max_val - scale_min_val)
    x *= 255
    return x

# %%
def get_batches(images, batch_size, shuffle=True):
    images = np.array(images)
    if shuffle:
        idx = np.arange(len(images))
        np.random.shuffle(idx)
        images = images[idx]
    n_batches = len(images)//batch_size
    for i in range(0, len(images), batch_size):
        x = images[i:i+batch_size]
        yield x

# %%
i = scale(images[0])
print(i.shape)
print(np.max(i), np.min(i))
# Out:
# (64, 64, 3)
# -0.992157 -0.998647

# %% [markdown]
# ## define network

# %%
# inputs
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(dtype=tf.float32, shape=(None, *real_dim), name="input_real")
    inputs_z = tf.placeholder(dtype=tf.float32, shape=(None, z_dim), name="input_z")

    return inputs_real, inputs_z

# %%
def generator(z, output_dim, reuse=False, alpha=0.2, is_train=True):
    alpha = 0.1
    with tf.variable_scope('generator', reuse=not is_train):
        # First fully connected layer
        fc = tf.layers.dense(inputs=z, units=8*8*1024, activation=None)
        conv1 = tf.reshape(fc, shape=(-1, 8, 8, 1024))
        conv1 = tf.layers.batch_normalization(inputs=conv1, training=is_train)
        conv1 = tf.maximum(conv1, alpha*conv1)
        # > 8*8
        
        conv2 = tf.layers.conv2d_transpose(inputs=conv1, filters=128, kernel_size=5, strides=2, padding='SAME', activation=None)
        conv2 = tf.layers.batch_normalization(inputs=conv2, training=is_train)
        conv2 = tf.maximum(conv2, alpha*conv2)
        # > 16*16
        
        conv3 = tf.layers.conv2d_transpose(inputs=conv2, filters=256, kernel_size=5, strides=2, padding='SAME', activation=None)
        conv3 = tf.layers.batch_normalization(inputs=conv3, training=is_train)
        conv3 = tf.maximum(conv3, alpha*conv3)
        # > 32*32
        
        # Output layer, 64*64
        logits = tf.layers.conv2d_transpose(inputs=conv3, filters=output_dim, kernel_size=5, strides=2, padding='SAME', activation=None)
        
        out = tf.tanh(logits)
    
    return out

# %%
def discriminator(x, reuse=False, alpha=0.01):

    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 64*64
        conv1 = tf.layers.conv2d(inputs=x, filters=64, kernel_size=5, strides=2, padding='SAME', activation=None, kernel_initializer=tf.contrib.layers.xavier_initializer())
        conv1 = tf.maximum(conv1, alpha*conv1)
        # > 32*32
        
        conv2 = tf.layers.conv2d(inputs=conv1, filters=256, kernel_size=5, strides=2, padding='SAME', activation=None)
        conv2 = tf.layers.batch_normalization(inputs=conv2, training=True)
        conv2 = tf.maximum(conv2, alpha*conv2)
        # > 16*16

        conv3 = tf.layers.conv2d(inputs=conv2, filters=1024, kernel_size=5, strides=2, padding='SAME', activation=None)
        conv3 = tf.layers.batch_normalization(inputs=conv3, training=True)
        conv3 = tf.maximum(conv3, alpha*conv3)
        # > 8*8
        
        flat = tf.reshape(conv2, (-1, 8*8*1024))
        logits = tf.layers.dense(inputs=flat, units=1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %%
def model_loss(input_real, input_z, output_dim, alpha=0.2):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    g_model = generator(input_z, output_dim, alpha=alpha)
    d_model_real, d_logits_real = discriminator(input_real, alpha=alpha)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True, alpha=alpha)

    smooth_factor = 0.1 # reduce true "correct" by this factor
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real) * (1 - smooth_factor)))
    
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss

# %%
def model_opt(d_loss, g_loss, learning_rate_d, learning_rate_g, beta1, beta2):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate_d, beta1=beta1, beta2=beta2).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate_g, beta1=beta1, beta2=beta2).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt

# %%
class GAN:
    def __init__(self, real_size, z_size, learning_rate_d, learning_rate_g, alpha=0.2, beta1=0.5, beta2=0.5):
        tf.reset_default_graph()
        
        self.input_real, self.input_z = model_inputs(real_size, z_size)
        
        self.d_loss, self.g_loss = model_loss(self.input_real, self.input_z,
                                              real_size[2], alpha=0.2)
        
        self.d_opt, self.g_opt = model_opt(self.d_loss, self.g_loss, learning_rate_d, learning_rate_g, beta1, beta2)

# %%
def view_samples(epoch, samples, nrows, ncols, figsize=(5,5)):
    fig, axes = plt.subplots(figsize=figsize, nrows=nrows, ncols=ncols, 
                             sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.axis('off')
        img = (unscale(img)).astype(np.uint8)
        im = ax.imshow(img, aspect='equal')
   
    plt.subplots_adjust(wspace=0, hspace=0)
    return fig, axes

# %%
def train(net, images, epochs, batch_size, print_every=10, show_every=30, figsize=(5,5)):
    saver = tf.train.Saver()
    sample_z = np.random.uniform(-1, 1, size=(72, z_size))

    samples, losses = [], []
    steps = 0

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for e in range(epochs):
            for x in get_batches(images, batch_size):
                steps += 1
                x = [scale(i) for i in x]

                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))

                # Run optimizers
                _ = sess.run(net.d_opt, feed_dict={net.input_real: x, net.input_z: batch_z})
                _ = sess.run(net.g_opt, feed_dict={net.input_z: batch_z, net.input_real: x})
                #_ = sess.run(net.g_opt, feed_dict={net.input_z: batch_z, net.input_real: x})

                if steps % print_every == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = net.d_loss.eval({net.input_z: batch_z, net.input_real: x})
                    train_loss_g = net.g_loss.eval({net.input_z: batch_z})

                    print("Epoch {}/{}...".format(e+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    # Save losses to view after training
                    losses.append((train_loss_d, train_loss_g))

                if steps % show_every == 0:
                    gen_samples = sess.run(
                                   generator(net.input_z, 3, reuse=True, is_train=False),
                                   feed_dict={net.input_z: sample_z})
                    samples.append(gen_samples)
                    _ = view_samples(-1, samples, 6, 12, figsize=figsize)
                    plt.show()

        saver.save(sess, './checkpoints/generator.ckpt')

    with open('samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    return losses, samples

# %%
# hyper params
real_size = (64,64,3)
z_size = 128
learning_rate_d = 0.0003
learning_rate_g = 0.001
batch_size = 32
epochs = 5000
beta1 = 0.5

# Create the network
net = GAN(real_size, z_size, learning_rate_d, learning_rate_g, beta1=beta1)

# %%
# Load the data and train the network here
losses, samples = train(net, images, epochs, batch_size, print_every=30, show_every=800, figsize=(10,5))
# Out:
# Epoch 30/5000... Discriminator Loss: 0.7738... Generator Loss: 2.2306
# Epoch 60/5000... Discriminator Loss: 0.3375... Generator Loss: 5.7688
# Epoch 90/5000... Discriminator Loss: 0.4441... Generator Loss: 8.7316
# Epoch 120/5000... Discriminator Loss: 0.4205... Generator Loss: 8.8689
# Epoch 150/5000... Discriminator Loss: 0.3730... Generator Loss: 9.1806
# Epoch 180/5000... Discriminator Loss: 0.3312... Generator Loss: 9.0146
# Epoch 210/5000... Discriminator Loss: 0.3289... Generator Loss: 7.1698
# Epoch 240/5000... Discriminator Loss: 0.3253... Generator Loss: 8.9911
# Epoch 270/5000... Discriminator Loss: 0.3252... Generator Loss: 9.1154
# Epoch 300/5000... Discriminator Loss: 0.3439... Generator Loss: 7.9969
# Epoch 330/5000... Discriminator Loss: 0.3370... Generator Loss: 6.8093
# Epoch 360/5000... Discriminator Loss: 0.3256... Generator Loss: 9.5674
# Epoch 390/5000... Discriminator Loss: 0.3307... Generator Loss: 10.7395
# Epoch 420/5000... Discriminator Loss: 0.3323... Generator Loss: 11.5993
# Epoch 450/5000... Discriminator Loss: 0.3259... Generator Loss: 9.1253
# Epoch 480/5000... Discriminator Loss: 0.3252... Generator Loss: 11.2681
# Epoch 510/5000... Discriminator Loss: 0.3311... Generator Loss: 13.1558
# Epoch 540/5000... Discriminator Loss: 0.3304... Generator Loss: 13.6395
# Epoch 570/5000... Discriminator Loss: 0.3307... Generator Loss: 11.2319
# Epoch 600/5000... Discriminator Loss: 0.3274... Generator Loss: 14.0813
# Epoch 630/5000... Discriminator Loss: 0.3338... Generator Loss: 12.5586
# Epoch 660/5000... Discriminator Loss: 0.3295... Generator Loss: 10.7010
# Epoch 690/5000... Discriminator Loss: 0.3255... Generator Loss: 9.2500
# Epoch 720/5000... Discriminator Loss: 0.3262... Generator Loss: 15.4735
# Epoch 750/5000... Discriminator Loss: 0.3271... Generator Loss: 11.7578
# Epoch 780/5000... Discriminator Loss: 0.3273... Generator Loss: 14.2883
# Epoch 810/5000... Discriminator Loss: 0.3251... Generator Loss: 12.1475
# Epoch 840/5000... Discriminator Loss: 0.3263... Generator Loss: 13.3540
# Epoch 870/5000... Discriminator Loss: 0.3268... Generator Loss: 14.2828
# Epoch 900/5000... Discriminator Loss: 0.3252... Generator Loss: 11.4853
# Epoch 930/5000... Discriminator Loss: 0.3255... Generator Loss: 9.5939
# Epoch 960/5000... Discriminator Loss: 0.3288... Generator Loss: 9.3890
# Epoch 990/5000... Discriminator Loss: 0.3276... Generator Loss: 12.2427
# Epoch 1020/5000... Discriminator Loss: 0.3252... Generator Loss: 14.1072
# Epoch 1050/5000... Discriminator Loss: 0.3255... Generator Loss: 8.8371
# Epoch 1080/5000... Discriminator Loss: 0.3253... Generator Loss: 16.1068
# Epoch 1110/5000... Discriminator Loss: 0.3255... Generator Loss: 8.8716
# Epoch 1140/5000... Discriminator Loss: 0.3265... Generator Loss: 12.2446
# Epoch 1170/5000... Discriminator Loss: 0.3255... Generator Loss: 10.8467
# Epoch 1200/5000... Discriminator Loss: 0.3251... Generator Loss: 13.7527
# Epoch 1230/5000... Discriminator Loss: 0.3278... Generator Loss: 12.0791
# Epoch 1260/5000... Discriminator Loss: 0.3254... Generator Loss: 13.5771
# Epoch 1290/5000... Discriminator Loss: 0.3252... Generator Loss: 14.2980
# Epoch 1320/5000... Discriminator Loss: 0.3255... Generator Loss: 12.0247
# Epoch 1350/5000... Discriminator Loss: 0.3292... Generator Loss: 13.0548
# Epoch 1380/5000... Discriminator Loss: 0.3251... Generator Loss: 11.3332
# Epoch 1410/5000... Discriminator Loss: 0.3255... Generator Loss: 11.9413
# Epoch 1440/5000... Discriminator Loss: 0.3288... Generator Loss: 8.5016
# Epoch 1470/5000... Discriminator Loss: 0.3257... Generator Loss: 11.0388
# Epoch 1500/5000... Discriminator Loss: 0.3251... Generator Loss: 15.4426
# Epoch 1530/5000... Discriminator Loss: 0.3266... Generator Loss: 14.1572
# Epoch 1560/5000... Discriminator Loss: 0.3251... Generator Loss: 13.4996
# Epoch 1590/5000... Discriminator Loss: 0.3264... Generator Loss: 13.9112
# Epoch 1620/5000... Discriminator Loss: 0.3267... Generator Loss: 12.9319
# Epoch 1650/5000... Discriminator Loss: 0.3254... Generator Loss: 8.9827
# Epoch 1680/5000... Discriminator Loss: 0.3254... Generator Loss: 13.4962
# Epoch 1710/5000... Discriminator Loss: 0.3251... Generator Loss: 10.2905
# Epoch 1740/5000... Discriminator Loss: 0.3252... Generator Loss: 11.7257
# Epoch 1770/5000... Discriminator Loss: 0.3254... Generator Loss: 14.2245
# Epoch 1800/5000... Discriminator Loss: 0.3255... Generator Loss: 13.0936
# Epoch 1830/5000... Discriminator Loss: 0.3251... Generator Loss: 14.6884
# Epoch 1860/5000... Discriminator Loss: 0.3256... Generator Loss: 16.8374
# Epoch 1890/5000... Discriminator Loss: 0.3252... Generator Loss: 11.7325
# Epoch 1920/5000... Discriminator Loss: 0.3255... Generator Loss: 16.8417
# Epoch 1950/5000... Discriminator Loss: 0.3252... Generator Loss: 13.7902
# Epoch 1980/5000... Discriminator Loss: 0.3264... Generator Loss: 13.6466
# Epoch 2010/5000... Discriminator Loss: 0.3275... Generator Loss: 15.5056
# Epoch 2040/5000... Discriminator Loss: 0.3263... Generator Loss: 15.7972
# Epoch 2070/5000... Discriminator Loss: 0.3251... Generator Loss: 13.3728
# Epoch 2100/5000... Discriminator Loss: 0.3262... Generator Loss: 13.7365
# Epoch 2130/5000... Discriminator Loss: 0.3255... Generator Loss: 15.1794
# Epoch 2160/5000... Discriminator Loss: 0.3252... Generator Loss: 13.7709
# Epoch 2190/5000... Discriminator Loss: 0.3264... Generator Loss: 14.5849
# Epoch 2220/5000... Discriminator Loss: 0.3264... Generator Loss: 13.0635
# Epoch 2250/5000... Discriminator Loss: 0.3251... Generator Loss: 11.5643
# Epoch 2280/5000... Discriminator Loss: 0.3258... Generator Loss: 11.3710
# Epoch 2310/5000... Discriminator Loss: 0.3266... Generator Loss: 17.2519
# Epoch 2340/5000... Discriminator Loss: 0.3254... Generator Loss: 12.5228
# Epoch 2370/5000... Discriminator Loss: 0.3260... Generator Loss: 13.4135
# Epoch 2400/5000... Discriminator Loss: 0.3255... Generator Loss: 10.2435
# Epoch 2430/5000... Discriminator Loss: 0.3252... Generator Loss: 12.2173
# Epoch 2460/5000... Discriminator Loss: 0.3252... Generator Loss: 12.3625
# Epoch 2490/5000... Discriminator Loss: 0.3251... Generator Loss: 15.0134
# Epoch 2520/5000... Discriminator Loss: 0.3261... Generator Loss: 17.8394
# Epoch 2550/5000... Discriminator Loss: 0.3263... Generator Loss: 16.4786
# Epoch 2580/5000... Discriminator Loss: 0.3258... Generator Loss: 10.4377
# Epoch 2610/5000... Discriminator Loss: 0.3251... Generator Loss: 15.2706
# Epoch 2640/5000... Discriminator Loss: 0.3251... Generator Loss: 13.9948
# Epoch 2670/5000... Discriminator Loss: 0.3251... Generator Loss: 12.3958
# Epoch 2700/5000... Discriminator Loss: 0.3256... Generator Loss: 12.0089
# Epoch 2730/5000... Discriminator Loss: 0.3255... Generator Loss: 13.3763
# Epoch 2760/5000... Discriminator Loss: 0.3252... Generator Loss: 11.5428
# Epoch 2790/5000... Discriminator Loss: 0.3251... Generator Loss: 11.6965
# Epoch 2820/5000... Discriminator Loss: 0.3251... Generator Loss: 13.0785
# Epoch 2850/5000... Discriminator Loss: 0.3251... Generator Loss: 12.5918
# Epoch 2880/5000... Discriminator Loss: 0.3252... Generator Loss: 14.1492
# Epoch 2910/5000... Discriminator Loss: 0.3269... Generator Loss: 13.9336
# Epoch 2940/5000... Discriminator Loss: 0.3252... Generator Loss: 12.1808
# Epoch 2970/5000... Discriminator Loss: 0.3252... Generator Loss: 15.4839
# Epoch 3000/5000... Discriminator Loss: 0.3254... Generator Loss: 12.8311
# Epoch 3030/5000... Discriminator Loss: 0.3260... Generator Loss: 13.5973
# Epoch 3060/5000... Discriminator Loss: 0.3251... Generator Loss: 14.7013
# Epoch 3090/5000... Discriminator Loss: 0.3259... Generator Loss: 10.0968
# Epoch 3120/5000... Discriminator Loss: 0.3262... Generator Loss: 16.8947
# Epoch 3150/5000... Discriminator Loss: 0.3253... Generator Loss: 13.0005
# Epoch 3180/5000... Discriminator Loss: 0.3256... Generator Loss: 12.7237
# Epoch 3210/5000... Discriminator Loss: 0.3252... Generator Loss: 13.9672
# Epoch 3240/5000... Discriminator Loss: 0.3252... Generator Loss: 15.5639
# Epoch 3270/5000... Discriminator Loss: 0.3251... Generator Loss: 12.4055
# Epoch 3300/5000... Discriminator Loss: 0.3254... Generator Loss: 15.0861
# Epoch 3330/5000... Discriminator Loss: 0.3255... Generator Loss: 14.2719
# Epoch 3360/5000... Discriminator Loss: 0.3251... Generator Loss: 14.9036
# Epoch 3390/5000... Discriminator Loss: 0.3257... Generator Loss: 11.1170
# Epoch 3420/5000... Discriminator Loss: 0.3251... Generator Loss: 12.7914
# Epoch 3450/5000... Discriminator Loss: 0.3251... Generator Loss: 12.8264
# Epoch 3480/5000... Discriminator Loss: 0.3251... Generator Loss: 13.3275
# Epoch 3510/5000... Discriminator Loss: 0.3251... Generator Loss: 13.0885
# Epoch 3540/5000... Discriminator Loss: 0.3254... Generator Loss: 13.2068
# Epoch 3570/5000... Discriminator Loss: 0.3254... Generator Loss: 12.9807
# Epoch 3600/5000... Discriminator Loss: 0.3252... Generator Loss: 13.0030
# Epoch 3630/5000... Discriminator Loss: 0.3255... Generator Loss: 13.5260
# Epoch 3660/5000... Discriminator Loss: 0.3257... Generator Loss: 14.4296
# Epoch 3690/5000... Discriminator Loss: 0.3253... Generator Loss: 16.5901
# Epoch 3720/5000... Discriminator Loss: 0.3254... Generator Loss: 13.7416
# Epoch 3750/5000... Discriminator Loss: 0.3252... Generator Loss: 13.7556
# Epoch 3780/5000... Discriminator Loss: 0.3255... Generator Loss: 16.7754
# Epoch 3810/5000... Discriminator Loss: 0.3252... Generator Loss: 13.1600
# Epoch 3840/5000... Discriminator Loss: 0.3259... Generator Loss: 16.1476
# Epoch 3870/5000... Discriminator Loss: 0.3251... Generator Loss: 12.2405
# Epoch 3900/5000... Discriminator Loss: 0.3251... Generator Loss: 11.5808
# Epoch 3930/5000... Discriminator Loss: 0.3253... Generator Loss: 14.5148
# Epoch 3960/5000... Discriminator Loss: 0.3256... Generator Loss: 13.7814
# Epoch 3990/5000... Discriminator Loss: 0.3252... Generator Loss: 12.3528
# Epoch 4020/5000... Discriminator Loss: 0.3256... Generator Loss: 15.9523
# Epoch 4050/5000... Discriminator Loss: 0.3252... Generator Loss: 14.4390
# Epoch 4080/5000... Discriminator Loss: 0.3254... Generator Loss: 14.7332
# Epoch 4110/5000... Discriminator Loss: 0.3264... Generator Loss: 13.6158
# Epoch 4140/5000... Discriminator Loss: 0.3264... Generator Loss: 16.2504
# Epoch 4170/5000... Discriminator Loss: 0.3252... Generator Loss: 16.3973
# Epoch 4200/5000... Discriminator Loss: 0.3252... Generator Loss: 16.2596
# Epoch 4230/5000... Discriminator Loss: 0.3255... Generator Loss: 16.3066
# Epoch 4260/5000... Discriminator Loss: 0.3252... Generator Loss: 15.8615
# Epoch 4290/5000... Discriminator Loss: 0.3251... Generator Loss: 13.6347
# Epoch 4320/5000... Discriminator Loss: 0.3261... Generator Loss: 16.0645
# Epoch 4350/5000... Discriminator Loss: 0.3252... Generator Loss: 11.4983
# Epoch 4380/5000... Discriminator Loss: 0.3260... Generator Loss: 14.3177
# Epoch 4410/5000... Discriminator Loss: 0.3252... Generator Loss: 12.6938
# Epoch 4440/5000... Discriminator Loss: 0.3251... Generator Loss: 12.4686
# Epoch 4470/5000... Discriminator Loss: 0.3256... Generator Loss: 11.4859
# Epoch 4500/5000... Discriminator Loss: 0.3253... Generator Loss: 12.2987
# Epoch 4530/5000... Discriminator Loss: 0.3253... Generator Loss: 14.5172
# Epoch 4560/5000... Discriminator Loss: 0.3251... Generator Loss: 12.9183
# Epoch 4590/5000... Discriminator Loss: 0.3253... Generator Loss: 15.1182
# Epoch 4620/5000... Discriminator Loss: 0.3252... Generator Loss: 12.4621
# Epoch 4650/5000... Discriminator Loss: 0.3251... Generator Loss: 15.4410
# Epoch 4680/5000... Discriminator Loss: 0.3251... Generator Loss: 14.0491
# Epoch 4710/5000... Discriminator Loss: 0.3258... Generator Loss: 16.7220
# Epoch 4740/5000... Discriminator Loss: 0.3253... Generator Loss: 11.9811
# Epoch 4770/5000... Discriminator Loss: 0.3253... Generator Loss: 14.3070
# Epoch 4800/5000... Discriminator Loss: 0.3252... Generator Loss: 10.9569
# Epoch 4830/5000... Discriminator Loss: 0.3251... Generator Loss: 11.6451
# Epoch 4860/5000... Discriminator Loss: 0.3257... Generator Loss: 15.4477
# Epoch 4890/5000... Discriminator Loss: 0.3251... Generator Loss: 13.9880
# Epoch 4920/5000... Discriminator Loss: 0.3255... Generator Loss: 12.5358
# Epoch 4950/5000... Discriminator Loss: 0.3253... Generator Loss: 11.5348
# Epoch 4980/5000... Discriminator Loss: 0.3251... Generator Loss: 13.2618

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
_ = view_samples(-1, samples, 6, 12, figsize=(10,5))
